# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 30
df = pd.read_csv('movies_metadata.csv', low_memory= False)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.genres[0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df.spoken_languages[0]
# Out:
# "[{'iso_639_1': 'en', 'name': 'English'}]"

# %%
df.drop(columns = ['adult','imdb_id','original_title','video','homepage'], inplace=True)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
import json 
import ast
# ast abstract syntax trees

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# ...

# %%
#handling stringified json columns 

df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
# # the above is not correct json format so json methods will not work on it 
# the correct format is 

# '{"": ,"": }'
# so we need to replace double quotes by single quotes and vice versa 

# replacing double quotes by single and vice versa

# json1 = "{'dog':3,'cat':5}" # wrong format json string 

# json.loads(json1) # this will throw an error

json2 = '{"dog":3,"cat":5}' # correct format 

json.loads(json2)

# the loads methods parses a valid json string and converts it to a
# python dictionary
# Out:
# {'dog': 3, 'cat': 5}

# %%
# example method  
# converting the json1 strting to corrct json format 
json1 = "{'dog':3,'cat':5}"
modified_json1=json1.replace("'",'"')
json.loads(modified_json1)
# Out:
# {'dog': 3, 'cat': 5}

# %%
# to do it for the entire column 
df.genres.apply(lambda x: json.loads(x.replace("'",'"')))
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
# the above is a three step process
#  we can do the same with an alternative method

# %%
ast.literal_eval(json2) # literal_eval reads the string in argument 
# and evaluates it to the cirrect format
# Out:
# {'dog': 3, 'cat': 5}

# %%
ast.literal_eval(json1)
# Out:
# {'dog': 3, 'cat': 5}

# %%
df.genres = df.genres.apply(ast.literal_eval)

# %%
json_col = ["belongs_to_collection", "genres", "production_countries", 
            "production_companies", "spoken_languages"]

# %%
df.loc[:,json_col].apply(ast.literal_eval, axis=0)
# here we haev ) in some colc thsere we would need some ither method
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-22ebfbbe8089> in <module>
# ----> 1 df.loc[:,json_col].apply(ast.literal_eval, axis=0)
#       2 # here we haev ) in some colc thsere we would need some ither method
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ...

# %%
import numpy as np

# %%
df.belongs_to_collection
# the literral eval should only be passed to a string
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
# checkimg each row whether string or not 
df.belongs_to_collection.apply(lambda x: isinstance(x,str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df.belongs_to_collection =df.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan
                              
                              
                              
                              
                              )

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df.production_countries= df.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
# now instead of having stringified json we have lists and dicts we converted to

# %%
df.belongs_to_collection
# say we want just the name column from the nested column
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x,dict) else np.nan)

# %%
df.belongs_to_collection.value_counts(dropna= False)
# Out:
# NaN                              40975
# The Bowery Boys                     29
# Totò Collection                     27
# James Bond Collection               26
# Zatôichi: The Blind Swordsman       26
#                                  ...
# I Love a Mystery movie series        1
# The Hobgoblin Collection             1
# Åsa-Nisse Collection                 1
# We're the Millers Collection         1
# The Postman Collection               1
# Name: belongs_to_collection, Length: 1696, dtype: int64

# %%
df.genres[0]

# here it is a list 
# here the aim would be to pick the three genres and put it in 
# one string seperated by |
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres = df.genres.apply(lambda x: "|".join(i['name'] for i in x))

#redo

# %%
# join() concatenates seqence of string passed to the argument with a 
# seperator specified 
# syntax sep.join(sequence of string)

df.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 45461                Drama|Family
# 45462                       Drama
# 45463       Action|Drama|Thriller
# 45464
# 45465
# Name: genres, Length: 45466, dtype: object

# %%
df.genres.value_counts()
# Out:
# Drama                                         5000
# Comedy                                        3621
# Documentary                                   2723
#                                               2442
# Drama|Romance                                 1301
#                                               ...
# Romance|Drama|Action|Comedy                      1
# Mystery|Fantasy|Horror                           1
# Adventure|Fantasy|Science Fiction|Action         1
# Adventure|Science Fiction|Thriller|Mystery       1
# Animation|Horror|Mystery|Science Fiction         1
# Name: genres, Length: 4069, dtype: int64

# %%
# 2442 missing values

# %%
df.genres.replace(" ", np.nan, inplace= True)

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.spoken_languages = df.spoken_languages.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x,list)else np.nan)

# %%
df.spoken_languages.value_counts(dropna= False)
# Out:
# English                                                                                                    22395
#                                                                                                             3952
# Français                                                                                                    1853
# 日本語                                                                                                         1289
# Italiano                                                                                                    1218
#                                                                                                            ...
# Deutsch|Français|Latin|العربية|ελληνικά|English                                                                1
# English|Deutsch|Español|Français|Italiano|Português|suomi|Pусский|Український|广州话 / 廣州話|日本語|한국어/조선말|普通话        1
# ...

# %%
df.spoken_languages.replace("",np.nan , inplace= True)

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries = df.production_countries.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.production_countries.replace("", np.nan, inplace = True)

# %%
df.production_countries
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45461                        Iran
# 45462                 Philippines
# 45463    United States of America
# 45464                      Russia
# 45465              United Kingdom
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_companies
# Out:
# 0           [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1        [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3        [{'name': 'Twentieth Century Fox Film Corporat...
# 4        [{'name': 'Sandollar Productions', 'id': 5842}...
#                                ...
# 45461                                                   []
# 45462               [{'name': 'Sine Olivia', 'id': 19653}]
# 45463    [{'name': 'American World Pictures', 'id': 6165}]
# 45464                 [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                   []
# Name: production_companies, Length: 45466, dtype: object

# %%
df.production_companies = df.production_companies.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
#df.production_companies.replace("", np.nan, inplace = True)

df.production_companies
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 45461   NaN
# 45462   NaN
# 45463   NaN
# 45464   NaN
# 45465   NaN
# Name: production_companies, Length: 45466, dtype: float64

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                       0
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     45466
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv("movies_metadata.csv", low_memory=False).isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# finding empty spaces and filling with Nan is also part of data cleaning
# having too many nans does not mean data is is unclean

# %%
df
# Out:
#                 belongs_to_collection    budget                    genres  \
# 0                Toy Story Collection  30000000   Animation|Comedy|Family
# 1                                 NaN  65000000  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection         0            Romance|Comedy
# 3                                 NaN  16000000      Comedy|Drama|Romance
# 4      Father of the Bride Collection         0                    Comedy
# ...                               ...       ...                       ...
# 45461                             NaN         0              Drama|Family
# 45462                             NaN         0                     Drama
# 45463                             NaN         0     Action|Drama|Thriller
# 45464                             NaN         0
# 45465                             NaN         0
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# ...

# %%
# problem with production companies column

# %%
#changing numerical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
df.budget.astype('float') # here we have mixed datatypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-269-7ed208661202> in <module>
# ----> 1 df.budget.astype('float')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
df.budget = pd.to_numeric(df.budget, errors="coerce")
# with error coerce we can fill missing value

# %%
df.budget.value_counts()
# here 0 is for the missing value as 0 cannot be budget of a movie
# Out:
# 0.0           36573
# 5000000.0       286
# 10000000.0      259
# 20000000.0      243
# 2000000.0       242
#               ...
# 4490331.0         1
# 313411.0          1
# 1020000.0         1
# 37.0              1
# 9500.0            1
# Name: budget, Length: 1223, dtype: int64

# %%
df.budget = df.budget.replace(0, np.nan)
# now 0 is not helpful it is better to have nan so we replace 0 with nan

# %%
# now the budget can be very high to improve readability we convert it to 
# million dollars 

df.budget = df.budget.div(1000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
# let us go to revenue column

# %%
df.revenue.value_counts(dropna = False)
# Out:
# 0.0            38052
# 12000000.0        20
# 10000000.0        19
# 11000000.0        19
# 2000000.0         18
#                ...
# 245724603.0        1
# 12212123.0         1
# 8203235.0          1
# 25900.0            1
# 12032983.0         1
# Name: revenue, Length: 6864, dtype: int64

# %%
df.revenue = df.revenue.replace(0,np.nan)

# %%
df.revenue = df.revenue.div(1000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
# renaming column names 

df.rename(columns = {"revenue":"revenue_musd", "budget":"budget_musd"}, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
df.runtime.value_counts(dropna = False)
# Out:
# 90.0      2556
# 0.0       1558
# 100.0     1470
# 95.0      1412
# 93.0      1214
#           ...
# 238.0        1
# 316.0        1
# 258.0        1
# 780.0        1
# 1256.0       1
# Name: runtime, Length: 354, dtype: int64

# %%
# runtime 0 is insensible 

df.runtime = df.runtime.replace(0, np.nan)

# %%
df.runtime
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45461     90.0
# 45462    360.0
# 45463     90.0
# 45464     87.0
# 45465     75.0
# Name: runtime, Length: 45466, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
# here id is object this could also be possibly numeric 

df.id = pd.to_numeric(df.id, errors="coerce")

# %%
df.id.value_counts()
#now movie id should not be dupliacte it should be unique
# Out:
# 141971.0    3
# 25541.0     2
# 13209.0     2
# 11115.0     2
# 10991.0     2
#            ..
# 41244.0     1
# 10518.0     1
# 55971.0     1
# 91070.0     1
# 1408.0      1
# Name: id, Length: 45433, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45463 non-null  float64
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
df.popularity = pd.to_numeric(df.popularity, errors='coerce')

# %%
df.popularity.value_counts()

# here it is fine we can have values with 0 popularity
# Out:
# 0.000000     66
# 0.000001     56
# 0.000308     43
# 0.000220     40
# 0.000844     38
#              ..
# 10.066776     1
# 0.954314      1
# 1.874027      1
# 0.512893      1
# 5.603312      1
# Name: popularity, Length: 43757, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45463 non-null  float64
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
df.vote_average.value_counts(dropna = False)
# having 0 avg is not making sense
# Out:
# 0.0    2998
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
#        ...
# 9.4       3
# 9.8       1
# 0.7       1
# 9.6       1
# 1.1       1
# Name: vote_average, Length: 92, dtype: int64

# %%
df.loc[df.vote_count ==0 ,"vote_average"]

# for movies where no one has voted we cannot conclud that avg voting rate 
# is 0
# it is incoclusive since no one voted
# so it is better to put nan
# Out:
# 83       0.0
# 107      0.0
# 126      0.0
# 132      0.0
# 137      0.0
#         ...
# 45432    0.0
# 45434    0.0
# 45452    0.0
# 45464    0.0
# 45465    0.0
# Name: vote_average, Length: 2899, dtype: float64

# %%
df.loc[df.vote_count ==0 ,"vote_average"] = np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45463 non-null  float64
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
# date time cleaning 

df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
pd.to_datetime(df.release_date, errors="coerce")
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45466, dtype: datetime64[ns]

# %%
df.release_date.value_counts(dropna=False)
# Out:
# 2008-01-01    136
# 2009-01-01    121
# 2007-01-01    118
# 2005-01-01    111
# 2006-01-01    101
#              ...
# 1899-10-01      1
# 1997-03-08      1
# 1949-04-16      1
# 1999-08-12      1
# 1970-10-04      1
# Name: release_date, Length: 17337, dtype: int64

# %%
# cleaning string and text column s

df.overview[0]
# Out:
# "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences."

# %%
df.overview.value_counts(dropna = False).head(20)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     954
# ...

# %%
df.overview.replace("No overview found.", np.nan, inplace = True)

# %%
df.overview.replace("No Overview", np.nan, inplace = True)

# %%
df.overview.replace("No movie overview available.", np.nan, inplace = True)

# %%
df.overview.replace(" ", np.nan, inplace = True)

# %%
df.overview.replace("No overview yet.", np.nan, inplace = True)

# %%
df.tagline.value_counts(dropna = False).head(50)
# Out:
# NaN                                                                         25054
# Based on a true story.                                                          7
# -                                                                               4
# Trust no one.                                                                   4
# Be careful what you wish for.                                                   4
# Some doors should never be opened.                                              3
# A Love Story                                                                    3
# Which one is the first to return - memory or the murderer?                      3
# Classic Albums                                                                  3
# Drama                                                                           3
# How far would you go?                                                           3
# ...

# %%
df.tagline.replace("-", np.nan, inplace = True)

# %%
df.overview
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45466, dtype: object

# %%
# removing duplicates

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget_musd            8890 non-null   float64
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45463 non-null  float64
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44362 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45080 non-null  object
#  12  production_companies   0 non-null      float64
#  13  production_countries   45463 non-null  object
# ...

# %%
df.id.value_counts(dropna= False)
# Out:
# 141971.0    3
# NaN         3
# 12600.0     2
# 18440.0     2
# 42495.0     2
#            ..
# 41244.0     1
# 10518.0     1
# 55971.0     1
# 91070.0     1
# 1408.0      1
# Name: id, Length: 45434, dtype: int64

# %%
# remving duplicates where all columns identical in a row 


df[df.duplicated(keep=False)].sort_values(by="id")
# Out:
#        adult                              belongs_to_collection  budget_musd  \
# 7345   False                                                NaN          NaN
# 9165   False                                                NaN          NaN
# 24844  False                                                NaN          NaN
# 14012  False                                                NaN          NaN
# 22151  False                                                NaN          NaN
# 14000  False                                                NaN          NaN
# 8068   False                                                NaN          NaN
# 9327   False                                                NaN          NaN
# 17229  False                                                NaN          NaN
# 23044  False                                                NaN          NaN
# 29374  False                                                NaN          NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.id.value_counts(dropna=False)
# Out:
# NaN         3
# 22649.0     2
# 4912.0      2
# 14788.0     2
# 13209.0     2
#            ..
# 64572.0     1
# 103751.0    1
# 255885.0    1
# 175386.0    1
# 1408.0      1
# Name: id, Length: 45434, dtype: int64

# %%
# dropping duplicates where only id is same

df[df.duplicated(subset="id",keep=False)].sort_values(by="id")
# Out:
#                                                    adult  \
# 33826                                              False
# 5865                                               False
# 4114                                               False
# 44821                                              False
# 44826                                              False
# 5535                                               False
# 15765                                              False
# 11342                                              False
# 10419                                              False
# 12066                                              False
# 5130                                               False
# 33743                                              False
# 949                                                False
# 15074                                              False
# 9576                                               False
# ...

# %%
df.drop_duplicates(subset="id",inplace = True)

# %%
df.id.value_counts(dropna=False)
# Out:
# 287281.0    1
# 42323.0     1
# 42612.0     1
# 6473.0      1
# 38225.0     1
#            ..
# 37942.0     1
# 64572.0     1
# 103751.0    1
# 255885.0    1
# 1408.0      1
# Name: id, Length: 45434, dtype: int64

# %%
# handling missing values and removing  observations 


# there are three ways to deal with missing values 

# 1. do nothing and leave as they are
# 2. remove records that exceed a certain number of missing values 
# 3. replace mssing values with appropriate replacement values

# %%
#identification of missing values

# %%
df.isna().sum()
# gives column wise misisng null values or  missing values
# Out:
# adult                        0
# belongs_to_collection    40945
# budget_musd              36554
# genres                       0
# homepage                 37659
# id                           1
# imdb_id                     17
# original_language           11
# original_title               0
# overview                  1104
# popularity                   4
# poster_path                386
# production_companies     45434
# production_countries         3
# release_date                87
# revenue_musd             38036
# runtime                   1819
# spoken_languages             4
# status                      85
# tagline                  25037
# title                        4
# video                        4
# vote_average              2900
# vote_count                   4
# dtype: int64

# %%
# here we see id and title has missing values so we intend to remove them 

df[df.title.isna()]
# Out:
#                      adult                              belongs_to_collection  \
# 19729                False                                                NaN
# 19730   - Written by Ørnås                                           0.065736
# 29502                False  {'id': 122661, 'name': 'Mardock Scramble Colle...
# 35586                False                                                NaN
#
#        budget_musd                                             genres  \
# 19729          NaN  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 19730          NaN  [{'name': 'Carousel Productions', 'id': 11176}...
# 29502          NaN  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 35586          NaN  [{'id': 10770, 'name': 'TV Movie'}, {'id': 28,...
#
#                                                 homepage        id    imdb_id  \
# 19729                                                NaN   82663.0  tt0113002
# ...

# %%
# let us remove them 

df.dropna(subset=["id","title"],inplace=True)
# dropna drops all rows where there is atleast one na specified in the 
#subset parameter 
# since how specified by default as any

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40943
# budget_musd              36550
# genres                       0
# homepage                 37657
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                  1104
# popularity                   0
# poster_path                383
# production_companies     45430
# production_countries         0
# release_date                84
# revenue_musd             38032
# runtime                   1815
# spoken_languages             0
# status                      81
# tagline                  25033
# title                        0
# video                        0
# vote_average              2896
# vote_count                   0
# dtype: int64

# %%
# when we have missing values in a number type column the data type 
# is always float
# now since we removed missing value from id we can change the data type 
# to int 


df.id = df.id.astype("int")

# %%
df.notna().sum(axis=1).sort_values(ascending=False)
# Out:
# 42902    23
# 11492    23
# 24078    23
# 23957    23
# 23897    23
#          ..
# 44978    13
# 20166    13
# 31616    13
# 45070    13
# 41832    13
# Length: 45430, dtype: int64

# %%
df.dropna(thresh=10,inplace =True)
